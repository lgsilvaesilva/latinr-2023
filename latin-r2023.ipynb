# %% [raw]
# ---
# author:
#   - Luís G. Silva e Silva<br>Data Lab for Statistical Innovation<br>Food and Agriculture Organization of the United Nations
# format:
#   revealjs:
#     theme: [default, style.scss]
#     slide-number: c/t
#     incremental: true
#     width: 1600
#     height: 900
#     title-slide-attributes:
#       data-background-image: img/title-image.jpeg
#       data-background-size: cover
# execute:
#   eval: true
#   echo: true
# ---

# %% [markdown]
# ```{css, echo = F}
# .bg_karl {
#   position: relative;
#   z-index: 1;
# }
#
# .bg_karl::before {
#       content: "";
#       background-image: url('img/title-image.jpeg');
#       background-size: cover;
#       position: absolute;
#       top: 0px;
#       right: 0px;
#       bottom: 0px;
#       left: 0px;
#       opacity: 0.15;
#       z-index: -1;
# }
# ```
#
# ## {.bg_karl}
#
# <h1>Producing Early Warnings through</h1>
#
# <h1>[Online News]{.flow}</h1>
#
# <h2>with R</h2>
#
# <hr>
#
# <br><br>
#
# <h4 style="color: #414042;">Luís G. Silva e Silva</h4>
#
# <h4 style="color: #414042;">Data Scientist</h4>
#
# <h4 style="color: #414042;">[Data Lab for Statistical Innovation](https://www.fao.org/datalab/en)</h4>
#
# <h4 style="color: #414042;">18<sup>th</sup> October 2023</h4>
#
# <br>
#
# <h3>
#
# ![](https://www.fao.org/images/corporatelibraries/fao-logo/fao-logo-en.svg?sfvrsn=f64522b4_36){.absolute top="750" left="0" height="100"}
# ![](https://latin-r.com/img/logo.png){.absolute top="750" left="1250" width="300"}
#
#
# <!-- ##  {.title} -->
#
# <!-- ::: r-fit-text -->
#
# <!--  Producing Early Warnings  -->
#
# <!--  through  -->
#
# <!--  [Online News]{.flow}  -->
#
# <!--  With R -->
#
# <!-- ::: -->
#
# <!-- ::: footer -->
#
# <!-- [  ](google.com) -->
#
# <!-- ::: -->
